# %%
import pickle

# Load your graph
with open(r'data\Derm_Graph.pkl', 'rb') as f:
    G = pickle.load(f)

# Look at one node to see its "DNA"
sample_node = list(G.nodes())[0]
print(f"Sample Node Attributes: {G.nodes[sample_node]}")
# Out:
# Sample Node Attributes: {'label': 'Substance', 'name': 'picoxystrobin'}
